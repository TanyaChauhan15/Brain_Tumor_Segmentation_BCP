# %% [markdown]
# # PyTorch Basics Notebook
# ### Introduction to Tensors, Datasets, DataLoaders, CNNs, and U‑Net Building Blocks

# %% [markdown]
# ## Import Required Libraries

# %%
# !pip install torch torchvision torchaudio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting torch
#   Using cached torch-2.9.1-cp313-cp313-win_amd64.whl.metadata (30 kB)
# Collecting torchvision
#   Using cached torchvision-0.24.1-cp313-cp313-win_amd64.whl.metadata (5.9 kB)
# Collecting torchaudio
#   Using cached torchaudio-2.9.1-cp313-cp313-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: filelock in c:\users\tanya chauhan\appdata\roaming\python\python313\site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\tanya chauhan\appdata\roaming\python\python313\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\tanya chauhan\appdata\roaming\python\python313\site-packages (from torch) (1.14.0)
# Collecting networkx>=2.5.1 (from torch)
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: jinja2 in c:\users\tanya chauhan\appdata\roaming\python\python313\site-packages (from torch) (3.1.6)
# Collecting fsspec>=0.8.5 (from torch)
#   Using cached fsspec-2025.12.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: setuptools in c:\users\tanya chauhan\appdata\roaming\python\python313\site-packages (from torch) (80.9.0)
# Requirement already satisfied: numpy in c:\users\tanya chauhan\appdata\roaming\python\python313\site-packages (from torchvision) (2.2.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\tanya chauhan\appdata\roaming\python\python313\site-packages (from torchvision) (11.2.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\tanya chauhan\appdata\roaming\python\python313\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tanya chauhan\appdata\roaming\python\python313\site-packages (from jinja2->torch) (3.0.2)
# Using cached torch-2.9.1-cp313-cp313-win_amd64.whl (110.9 MB)
# Using cached torchvision-0.24.1-cp313-cp313-win_amd64.whl (4.3 MB)
# Using cached torchaudio-2.9.1-cp313-cp313-win_amd64.whl (665 kB)
# Using cached fsspec-2025.12.0-py3-none-any.whl (201 kB)
# Using cached networkx-3.6.1-py3-none-any.whl (2.1 MB)
# Installing collected packages: networkx, fsspec, torch, torchvision, torchaudio
#
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
#    -------- ------------------------------- 1/5 [fsspec]
#    -------- ------------------------------- 1/5 [fsspec]
#    -------- ------------------------------- 1/5 [fsspec]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ---------------- ----------------------- 2/5 [torch]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    ------------------------ --------------- 3/5 [torchvision]
#    -------------------------------- ------- 4/5 [torchaudio]
#    -------------------------------- ------- 4/5 [torchaudio]
#    -------------------------------- ------- 4/5 [torchaudio]
#    -------------------------------- ------- 4/5 [torchaudio]
#    ---------------------------------------- 5/5 [torchaudio]
#
# Successfully installed fsspec-2025.12.0 networkx-3.6.1 torch-2.9.1 torchaudio-2.9.1 torchvision-0.24.1
#   WARNING: The scripts torchfrtrace.exe and torchrun.exe are installed in 'C:\Users\Tanya Chauhan\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## PyTorch Tensors

# %%
# Creating tensors
x = torch.tensor([1.0, 2.0, 3.0])
y = torch.randn(3)  # random tensor

print(x)
print(y)

# Tensor operations
print('Addition:', x + y)
print('Mean:', x.mean())
# Out:
# tensor([1., 2., 3.])
# tensor([-0.1476, -0.6426,  1.4910])
# Addition: tensor([0.8524, 1.3574, 4.4910])
# Mean: tensor(2.)

# %% [markdown]
# ## Autograd Basics

# %%
# Enable gradient tracking
a = torch.tensor([2.0, 3.0], requires_grad=True)
b = (a * a).sum()
b.backward()
print(a.grad)  # derivative of x^2 is 2x
# Out:
# tensor([4., 6.])

# %% [markdown]
# ## Custom PyTorch Dataset

# %% [markdown]
# We simulate MRI-like slices using random arrays just for practice.

# %%
class RandomMRIDataset(Dataset):
    def __init__(self, length=100):
        self.length = length

    def __len__(self):
        return self.length

    def __getitem__(self, idx):
        image = torch.randn(1, 64, 64)      # fake MRI slice
        mask = (torch.randn(1, 64, 64) > 0).float()  # fake mask
        return image, mask

dataset = RandomMRIDataset()
img, msk = dataset[0]
img.shape, msk.shape
# Out:
# (torch.Size([1, 64, 64]), torch.Size([1, 64, 64]))

# %% [markdown]
# ## DataLoader

# %%
loader = DataLoader(dataset, batch_size=8, shuffle=True)

for images, masks in loader:
    print(images.shape, masks.shape)
    break
# Out:
# torch.Size([8, 1, 64, 64]) torch.Size([8, 1, 64, 64])

# %% [markdown]
# ## Building a Simple CNN

# %%
class SimpleCNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(1, 16, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(16, 32, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(32 * 16 * 16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        x = self.encoder(x)
        return self.classifier(x)

model = SimpleCNN()
print(model)
# Out:
# SimpleCNN(
#   (encoder): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=8192, out_features=1, bias=True)
#     (2): Sigmoid()
#   )
# )

# %% [markdown]
# ## Training Loop Example

# %%
model = SimpleCNN()
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)

for epoch in range(2):
    for images, masks in loader:
        optimizer.zero_grad()
        preds = model(images)
        loss = criterion(preds, torch.zeros_like(preds))  # dummy target
        loss.backward()
        optimizer.step()
    print(f'Epoch {epoch+1}, Loss: {loss.item():.4f}')
# Out:
# Epoch 1, Loss: 0.0000
# Epoch 2, Loss: 0.0000

# %% [markdown]
# ## U‑Net Building Blocks

# %%
def conv_block(in_channels, out_channels):
    return nn.Sequential(
        nn.Conv2d(in_channels, out_channels, 3, padding=1),
        nn.ReLU(),
        nn.Conv2d(out_channels, out_channels, 3, padding=1),
        nn.ReLU()
    )

sample = torch.randn(1, 1, 128, 128)
block = conv_block(1, 16)
output = block(sample)
output.shape
# Out:
# torch.Size([1, 16, 128, 128])

# %% [markdown]
# ## Exercises

# %% [markdown]
# 1. Modify `RandomMRIDataset` to return a resized (128×128) slice using interpolation.
# 2. Add another convolution layer to `SimpleCNN` and observe how the model size changes.
# 3. Implement a small encoder-decoder network (mini U-Net) using `conv_block`.
# 4. Write a custom Dice Loss function in PyTorch.
# 5. Train the CNN on the random dataset and plot the loss curve using matplotlib.

# %%
import torch
from torch.utils.data import Dataset
import torch.nn.functional as F

class RandomMRIDataset(Dataset):
    def __init__(self, length=100):
        self.length = length

    def __len__(self):
        return self.length

    def __getitem__(self, idx):
        image = torch.randn(1, 64, 64)
        mask = (torch.randn(1, 64, 64) > 0).float()

        # resize to 128x128
        image = F.interpolate(image.unsqueeze(0), size=(128, 128), mode='bilinear', align_corners=False)
        mask = F.interpolate(mask.unsqueeze(0), size=(128, 128), mode='nearest')

        return image.squeeze(0), mask.squeeze(0)

# %%
import torch.nn as nn

class SimpleCNN(nn.Module):
    def __init__(self):
        super().__init__()

        self.encoder = nn.Sequential(
            nn.Conv2d(1, 16, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(16, 32, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(32, 64, 3, padding=1),  # NEW LAYER
            nn.ReLU()
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(64 * 32 * 32, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        x = self.encoder(x)
        return self.classifier(x)

# %%
def conv_block(in_c, out_c):
    return nn.Sequential(
        nn.Conv2d(in_c, out_c, 3, padding=1),
        nn.ReLU(),
        nn.Conv2d(out_c, out_c, 3, padding=1),
        nn.ReLU()
    )

class MiniEncoderDecoder(nn.Module):
    def __init__(self):
        super().__init__()

        self.encoder = nn.Sequential(
            conv_block(1, 16),
            nn.MaxPool2d(2)
        )

        self.decoder = nn.Sequential(
            nn.Upsample(scale_factor=2, mode='nearest'),
            conv_block(16, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

# %%
import torch
import torch.nn as nn

class DiceLoss(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, preds, targets):
        preds = preds.view(-1)
        targets = targets.view(-1)

        intersection = (preds * targets).sum()
        dice = (2 * intersection) / (preds.sum() + targets.sum() + 1e-6)
        return 1 - dice

# %%
from torch.utils.data import DataLoader
import torch.optim as optim
import matplotlib.pyplot as plt

dataset = RandomMRIDataset()
loader = DataLoader(dataset, batch_size=8, shuffle=True)

model = SimpleCNN()
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)

losses = []

for epoch in range(3):
    for images, masks in loader:
        optimizer.zero_grad()
        preds = model(images)

        # dummy target (same as taught)
        loss = criterion(preds, torch.zeros_like(preds))
        loss.backward()
        optimizer.step()

    losses.append(loss.item())
    print(f"Epoch {epoch+1}, Loss: {loss.item():.4f}")

plt.plot(losses)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Loss Curve")
plt.show()
# Out:
# Epoch 1, Loss: 0.0000
# Epoch 2, Loss: 0.0000
# Epoch 3, Loss: 0.0000
